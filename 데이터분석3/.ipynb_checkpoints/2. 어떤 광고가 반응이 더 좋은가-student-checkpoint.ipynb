# %% [markdown]
# # 어떤 광고가 반응이 더 좋은가?
# #### 게임 개발회사 A는 지난 문제를 현명하게 해결하고 안정적인 영업을 하고 있으나, 매월 실시하고 있는 게임아이템 판매 이벤트에 대해 고객들의 구매율이 상대적으로 낮음을 확인하였음.
# #### 우리 회사는 맨날 무슨 일이 터지나?
# ![](2-1.jpg)

# %% [markdown]
# #### 유력 가설: 이벤트 공지 및 홍보 활동에 문제가 있다. 구체적으로 우리 게임에 대한 광고 클릭률이 항상 낮다고 한다.
# #### 해결책: 다양한 광고를 조사하고 비교해서 우리 게임 광고 클릭

# %% [markdown]
# ## 1. Loading data

# %% [markdown]
# #### 1) 필요한 라이브러리들을 호출

# %%
#데이터 분석에 필요한 패키지들을 파이썬으로 호출
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chisquare
# %matplotlib inline

# %% [markdown]
# #### 2) 각 변수별로 데이터 할당

# %%
imp = pd.read_csv('ab_test_imp.csv', sep=',')
goal = pd.read_csv('ab_test_goal.csv', sep=',')

# %% [markdown]
# ![](2-2.jpg)

# %% [markdown]
# #### 3) 호출된 데이터 정보 확인

# %%
imp.head()
# Out:
#      log_date app_name   test_name test_case  user_id  transaction_id
# 0  2017-10-01  game-01  sales_test         B    36703           25622
# 1  2017-10-01  game-01  sales_test         A    44339           25623
# 2  2017-10-01  game-01  sales_test         B    32087           25624
# 3  2017-10-01  game-01  sales_test         B    10160           25625
# 4  2017-10-01  game-01  sales_test         B    46113           25626

# %%
goal.head()
# Out:
#      log_date app_name   test_name test_case  user_id  transaction_id
# 0  2017-10-01  game-01  sales_test         B    15021           25638
# 1  2017-10-01  game-01  sales_test         B      351           25704
# 2  2017-10-01  game-01  sales_test         B     8276           25739
# 3  2017-10-01  game-01  sales_test         B     1230           25742
# 4  2017-10-01  game-01  sales_test         B    17471           25743

# %% [markdown]
# # 2. Data cleaning

# %% [markdown]
# #### 1) 각 데이터들을 결합

# %%
#두 데이터 결합하기 
ImpGoal = imp.merge(goal, on = ["transaction_id"])
ImpGoal.head(20)
# Out:
#     log_date_x app_name_x test_name_x test_case_x  user_id_x  transaction_id  \
# 0   2017-10-01    game-01  sales_test           B      15021           25638
# 1   2017-10-01    game-01  sales_test           A        596           25655
# 2   2017-10-01    game-01  sales_test           B        351           25704
# 3   2017-10-01    game-01  sales_test           A        130           25715
# 4   2017-10-01    game-01  sales_test           A      15809           25728
# 5   2017-10-01    game-01  sales_test           B       8276           25739
# 6   2017-10-01    game-01  sales_test           B       1230           25742
# 7   2017-10-01    game-01  sales_test           B      17471           25743
# 8   2017-10-01    game-01  sales_test           B      48728           25746
# 9   2017-10-01    game-01  sales_test           B      16929           25769
# 10  2017-10-01    game-01  sales_test           B      30111           25780
# 11  2017-10-01    game-01  sales_test           B      30328           25791
# 12  2017-10-01    game-01  sales_test           A      49543           25793
# 13  2017-10-01    game-01  sales_test           B      32453           25796
# 14  2017-10-01    game-01  sales_test           B      42210           25801
# 15  2017-10-01    game-01  sales_test           A      39282           25816
# 16  2017-10-01    game-01  sales_test           B       8668           25817
# 17  2017-10-01    game-01  sales_test           B      49547           25821
# 18  2017-10-01    game-01  sales_test           A      44353           25826
# 19  2017-10-01    game-01  sales_test           B      49552           25835
#
#     log_date_y app_name_y test_name_y test_case_y  user_id_y
# 0   2017-10-01    game-01  sales_test           B      15021
# 1   2017-10-01    game-01  sales_test           A        596
# 2   2017-10-01    game-01  sales_test           B        351
# 3   2017-10-01    game-01  sales_test           A        130
# 4   2017-10-01    game-01  sales_test           A      15809
# 5   2017-10-01    game-01  sales_test           B       8276
# 6   2017-10-01    game-01  sales_test           B       1230
# 7   2017-10-01    game-01  sales_test           B      17471
# 8   2017-10-01    game-01  sales_test           B      48728
# 9   2017-10-01    game-01  sales_test           B      16929
# 10  2017-10-01    game-01  sales_test           B      30111
# 11  2017-10-01    game-01  sales_test           B      30328
# 12  2017-10-01    game-01  sales_test           A      49543
# 13  2017-10-01    game-01  sales_test           B      32453
# 14  2017-10-01    game-01  sales_test           B      42210
# 15  2017-10-01    game-01  sales_test           A      39282
# 16  2017-10-01    game-01  sales_test           B       8668
# 17  2017-10-01    game-01  sales_test           B      49547
# 18  2017-10-01    game-01  sales_test           A      44353
# 19  2017-10-01    game-01  sales_test           B      49552

# %% [markdown]
# #### 2) 일자별 정렬을 위한 날짜 처리

# %%
# ImpGoal 데이터프레임 내 "log_date_x"시리즈를 datetime 유형으로 변경
ImpGoal['log-date_x'] = ImpGoal['log_date_x'].apply(lambda x: pd. to_datetime(str(x)))

# %% [markdown]
# #### 3) 광고별 클릭률 지표 설정

# %%
#"is.goal" 시리즈를 만들고 "user_id_y"값이 "true"이면 0, 그렇지 않으면 1으로 표시
ImpGoal['is_goal'] = np.where(pd.isnull(ImpGoal["user_id_y"]) == True, 0, 1)

# %%
ImpGoal.head()
# Out:
#    log_date_x app_name_x test_name_x test_case_x  user_id_x  transaction_id  \
# 0  2017-10-01    game-01  sales_test           B      15021           25638
# 1  2017-10-01    game-01  sales_test           A        596           25655
# 2  2017-10-01    game-01  sales_test           B        351           25704
# 3  2017-10-01    game-01  sales_test           A        130           25715
# 4  2017-10-01    game-01  sales_test           A      15809           25728
#
#    log_date_y app_name_y test_name_y test_case_y  user_id_y log-date_x  \
# 0  2017-10-01    game-01  sales_test           B      15021 2017-10-01
# 1  2017-10-01    game-01  sales_test           A        596 2017-10-01
# 2  2017-10-01    game-01  sales_test           B        351 2017-10-01
# 3  2017-10-01    game-01  sales_test           A        130 2017-10-01
# 4  2017-10-01    game-01  sales_test           A      15809 2017-10-01
#
#    is_goal
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %% [markdown]
# # 3. Data analysis

# %% [markdown]
# #### 1) 광고별 클릭률 확인

# %%
# 광고A와 광고B의 각 클릭률 비교
ImpGoal['is_goal'].groupby(ImpGoal['test_case_x']).mean()
# Out:
# test_case_x
# A    1
# B    1
# Name: is_goal, dtype: int32

# %% [markdown]
# #### 2) 각 광고별 클릭률 트렌드 확인

# %%
#"log_date_x" 기준에 따라 각 광고별 클릭률을 정렬
data = ImpGoal.groupby(["log_date_x", "test_case_x"])['is_goal'].mean()
data
# Out:
# log_date_x  test_case_x
# 2017-10-01  A              1
#             B              1
# 2017-10-02  A              1
#             B              1
# 2017-10-03  A              1
#             B              1
# 2017-10-04  A              1
#             B              1
# 2017-10-05  A              1
#             B              1
# 2017-10-06  A              1
#             B              1
# 2017-10-07  A              1
#             B              1
# 2017-10-08  A              1
#             B              1
# 2017-10-09  A              1
#             B              1
# 2017-10-10  A              1
#             B              1
# 2017-10-11  A              1
#             B              1
# 2017-10-12  A              1
#             B              1
# 2017-10-13  A              1
#             B              1
# 2017-10-14  A              1
#             B              1
# 2017-10-15  A              1
#             B              1
#                           ..
# 2017-10-17  A              1
#             B              1
# 2017-10-18  A              1
#             B              1
# 2017-10-19  A              1
#             B              1
# 2017-10-20  A              1
#             B              1
# 2017-10-21  A              1
#             B              1
# 2017-10-22  A              1
#             B              1
# 2017-10-23  A              1
#             B              1
# 2017-10-24  A              1
#             B              1
# 2017-10-25  A              1
#             B              1
# 2017-10-26  A              1
#             B              1
# 2017-10-27  A              1
#             B              1
# 2017-10-28  A              1
#             B              1
# 2017-10-29  A              1
#             B              1
# 2017-10-30  A              1
#             B              1
# 2017-10-31  A              1
#             B              1
# Name: is_goal, Length: 62, dtype: int32

# %% [markdown]
# # 4. Data Visualization

# %% [markdown]
# #### 1) 각 광고별 클릭률 트렌드 시각화

# %%
# unstack()함수를 이용해 완전한 데이터 정규화 수행
data = data.unstack('test_case_x')

# %%
data.head()
# Out:
# test_case_x  A  B
# log_date_x
# 2017-10-01   1  1
# 2017-10-02   1  1
# 2017-10-03   1  1
# 2017-10-04   1  1
# 2017-10-05   1  1

# %%
#완성된 데이터를 이용해 시각화 수행
data.plot.line(figsize=(15,7), style='--',
               marker='o',markersize=10, linewidth=2)
